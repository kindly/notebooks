# %% [markdown]
# # Coverage OCDS
#
# Try and analyse OCDS coverage using postgresql as much as possible, to see the extent we can use it as standard tool for analysing and storing OCDS data.

# %%
import noteql
import jsonref
import json
import io

# %% [markdown]
# Make a schema called "canada" in local db instance

# %%
session = noteql.Session('canada', dburi='postgresql://noteql:noteql@localhost/noteql')

# %% [markdown]
# Get a version of OCDS schema, flatten it and load it into the database. It is very hard to write such flattening in sql (mainly due to how difficult it is to resolve refs) so we resort to python.  However, this could processed once and stored for future use.
# This currently ignores pattern_properties but should work with any release schema.

# %%
deref_schema = jsonref.load_uri('http://standard.open-contracting.org/schema/1__0__2/release-schema.json')
def flat_generator(properties, current_path=tuple()):
    for key, value in properties.items():
        prop_type = value.get('type')
        if not prop_type:
            continue
        new_path = current_path + (key,)
        yield (new_path, prop_type)
        if 'object' in prop_type and 'properties' in value:
            yield from flat_generator(value['properties'], current_path=new_path)
        if 'array' in prop_type and 'items' in value and 'object' in value['items']['type']:
            yield from flat_generator(value['items']['properties'], current_path=new_path)
            
fields = [{"path": "/".join(key), "type": value} for key, value in dict(flat_generator(deref_schema['properties'])).items()]
fake_file = io.StringIO(json.dumps(fields))

session.load_json(fake_file, path_to_list='', table_name='schema_import', field_name='schema_path', overwrite=True)
# Out:
# Total rows loaded 347

# %% [markdown]
# Process the flattened schema.  Make a table with each field and all its children.

# %%
session.run_sql('''
drop table if exists schema_info;
select schema_path ->> 'path' "path", schema_path -> 'type' "type" into schema_info  from schema_import
''')

session.run_sql('''
drop table if exists schema_info_children;
select parent.path "path", child.path "child_path", parent.type into schema_info_children from schema_info parent, schema_info child where
 left(child.path, length(parent.path)) = parent.path
''')
# Out:
# 'Success'

# %% [markdown]
# Load and process the actual data. One row per release.

# %%
session.load_json('canada-15-16.json', path_to_list='releases', table_name='import', field_name='releases', overwrite=True)
session.run_sql('''
drop table if exists releases;
select releases->> 'id' release_id, releases->> 'ocid' ocid, releases into releases from import
''')
# Out:
# Total rows loaded 11105
# 'Success'

# %% [markdown]
# Flatten the actual data in SQL. This is fairly tricky to pull off as recursion primitives in pure sql are very limited.

# %%
session.run_sql('''
drop table if exists flattened;
WITH RECURSIVE all_paths(ocid, path, "value") AS (
    select ocid, 
       (key_value).key "path", 
       (key_value).value "value" from 
    (select ocid, jsonb_each(releases) key_value from releases) a
  UNION ALL
    (select ocid,
           case when key_value is not null then
               a.path || '/'::text || (key_value).key::text
           else
               a.path
           end "path",
           case when a.key_value is not null then
               (a.key_value).value
           else
               array_value
           end "value"
     from
        (select 
           ocid,
           path,
           jsonb_each(case when jsonb_typeof(value) = 'object' then value else '{}'::jsonb end) key_value,
           jsonb_array_elements(case when jsonb_typeof(value) = 'array' and jsonb_typeof(value -> 0) = 'object' then value else '[]'::jsonb end) "array_value"
           from all_paths
        ) a
   )
)
SELECT ocid, path,
   case when (jsonb_typeof(value) = 'array' and jsonb_typeof(value -> 0) = 'object') or jsonb_typeof(value) = 'object' then null else value end  
   into flattened
FROM all_paths
''')
# Out:
# 'Success'

# %% [markdown]
# Aggregate the flattened data with basic statistics.

# %%
session.run_sql('''
   drop table if exists flattened_stats;
   select path, 1 "exists", count(*) total, count(distinct ocid) distinct_ocid, count(distinct value) distinct_value into flattened_stats from flattened  group by 1
''')
# Out:
# 'Success'

# %% [markdown]
# Join schema with children with flattended stats.  This is to get stats about coverage by analysing all the decendants.

# %%
#session.run_sql('''
#   select 
#       si.path,
#       child_path,
#       coalesce(distinct_ocid, 0) distinct_ocid,
#       coalesce(exists, 0) "exists",
#       case when si.child_path <> si.path then 1 else 0 end total_fields
#   from schema_info_children si left join flattened_stats f on si.child_path = f.path and si.child_path <> si.path order by 1,2
#''')

session.run_sql('''
drop table if exists coverage_stats;
select path, distinct_ocid, exists, total_fields, distinct_ocid * total_fields overall_possible_distinct, sum_distinct_ocid, sum_distinct_ocid/(distinct_ocid * total_fields) as total_coverage, exists/total_fields as exists_coverage 
   into coverage_stats from 
   (select 
       si.path,
       (select count(distinct ocid) from flattened) distinct_ocid,
       sum(coalesce(distinct_ocid, 0.0)) sum_distinct_ocid,
       sum(coalesce(exists, 0.0)) "exists",
       count(*) total_fields  
   from schema_info_children si left join flattened_stats f on si.child_path = f.path group by 1 order by 1) a
''')
session.run_sql('''
select * from coverage_stats
''')
# Out:
# <table>
#     <thead>
#     <tr>
#
#         <th style="text-align: left; vertical-align: top">path</th>
#
#         <th style="text-align: left; vertical-align: top">distinct_ocid</th>
#
#         <th style="text-align: left; vertical-align: top">exists</th>
#
#         <th style="text-align: left; vertical-align: top">total_fields</th>
#
#         <th style="text-align: left; vertical-align: top">overall_possible_distinct</th>
#
#         <th style="text-align: left; vertical-align: top">sum_distinct_ocid</th>
#
#         <th style="text-align: left; vertical-align: top">total_coverage</th>
#
#         <th style="text-align: left; vertical-align: top">exists_coverage</th>
#
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr>
#
#               <td style="text-align: left; vertical-align: top">
#                 <pre>awards</pre>
#               </td>
#
#               <td style="text-align: left; vertical-align: top">
#                 <pre>10204</pre>
#               </td>
#
#               <td style="text-align: left; vertical-align: top">
#                 <pre>22.0</pre>
#               </td>
#
#               <td style="text-align: left; vertical-align: top">
#                 <pre>71</pre>
#               </td>
#
#               <td style="text-align: left; vertical-align: top">
#                 <pre>724484</pre>
#               </td>
#
#               <td style="text-align: left; vertical-align: top">
#                 <pre>77977.0</pre>
#               </td>
#
#               <td style="text-align: left; vertical-align: top">
#                 <pre>0.10763108640080388249</pre>
#               </td>
#
#               <td style="text-align: left; vertical-align: top">
#                 <pre>0.30985915492957746479</pre>
#               </td>
#
#         </tr>
#
#         <tr>
#
#               <td style="text-align: left; vertical-align: top">
#                 <pre>awards/amendment</pre>
#               </td>
#
#               <td style="text-align: left; vertical-align: top">
#                 <pre>10204</pre>
#               </td>
#
#               <td style="text-align: left; vertical-align: top">
#                 <pre>0.0</pre>
#               </td>
#
#               <td style="text-align: left; vertical-align: top">
#                 <pre>6</pre>
#               </td>
#
#               <td style="text-align: left; vertical-align: top">
#                 <pre>61224</pre>
#               </td>
#
#               <td style="text-align: left; vertical-align: top">
#                 <pre>0.0</pre>
#               </td>
#
#               <td style="text-align: left; vertical-align: top">
#                 <pre>0E-24</pre>
#               </td>
#
#               <td style="text-align: left; vertical-align: top">
#                 <pre>0E-20</pre>
#               </td>
#
#         </tr>
#
#         <tr>
#
#               <td style="text-align: left; vertical-align: top">
#                 <pre>awards/amendment/changes</pre>
#               </td>
#
#               <td style="text-align: left; vertical-align: top">
#                 <pre>10204</pre>
#               </td>
#
#               <td style="text-align: left; vertical-align: top">
#                 <pre>0.0</pre>
#               </td>
#
#               <td style="text-align: left; vertical-align: top">
#                 <pre>3</pre>
#               </td>
#
#               <td style="text-align: left; vertical-align: top">
#                 <pre>30612</pre>
#               </td>
#
#               <td style="text-align: left; vertical-align: top">
#                 <pre>0.0</pre>
#               </td>
#
#               <td style="text-align: left; vertical-align: top">
#                 <pre>0E-24</pre>
#               </td>
#
#               <td style="text-align: left; vertical-align: top">
#                 <pre>0E-20</pre>
#               </td>
#
#         </tr>
#
#         <tr>
#
#               <td style="text-align: left; vertical-align: top">
#                 <pre>awards/amendment/changes/former_value</pre>
#               </td>
#
#               <td style="text-align: left; vertical-align: top">
#                 <pre>10204</pre>
#               </td>
#
#               <td style="text-align: left; vertical-align: top">
#                 <pre>0.0</pre>
#               </td>
#
#               <td style="text-align: left; vertical-align: top">
#                 <pre>1</pre>
#               </td>
#
#               <td style="text-align: left; vertical-align: top">
#                 <pre>10204</pre>
#               </td>
#
#               <td style="text-align: left; vertical-align: top">
#                 <pre>0.0</pre>
#               </td>
#
#               <td style="text-align: left; vertical-align: top">
#                 <pre>0E-24</pre>
#               </td>
#
#               <td style="text-align: left; vertical-align: top">
#                 <pre>0E-20</pre>
#               </td>
#
#         </tr>
#
#         <tr>
#
#               <td style="text-align: left; vertical-align: top">
#                 <pre>awards/amendment/changes/property</pre>
#               </td>
#
#               <td style="text-align: left; vertical-align: top">
#                 <pre>10204</pre>
#               </td>
#
#               <td style="text-align: left; vertical-align: top">
#                 <pre>0.0</pre>
#               </td>
#
#               <td style="text-align: left; vertical-align: top">
#                 <pre>1</pre>
#               </td>
#
#               <td style="text-align: left; vertical-align: top">
#                 <pre>10204</pre>
#               </td>
#
#               <td style="text-align: left; vertical-align: top">
#                 <pre>0.0</pre>
#               </td>
#
#               <td style="text-align: left; vertical-align: top">
#                 <pre>0E-24</pre>
#               </td>
#
#               <td style="text-align: left; vertical-align: top">
#                 <pre>0E-20</pre>
#               </td>
#
#         </tr>
#
#         <tr>
#
#               <td style="text-align: left; vertical-align: top">
#                 <pre>awards/amendment/date</pre>
#               </td>
#
#               <td style="text-align: left; vertical-align: top">
#                 <pre>10204</pre>
#               </td>
#
#               <td style="text-align: left; vertical-align: top">
#                 <pre>0.0</pre>
#               </td>
#
#               <td style="text-align: left; vertical-align: top">
#                 <pre>1</pre>
#               </td>
#
#               <td style="text-align: left; vertical-align: top">
#                 <pre>10204</pre>
#               </td>
#
#               <td style="text-align: left; vertical-align: top">
#                 <pre>0.0</pre>
#               </td>
#
#               <td style="text-align: left; vertical-align: top">
#                 <pre>0E-24</pre>
#               </td>
#
#               <td style="text-align: left; vertical-align: top">
#                 <pre>0E-20</pre>
#               </td>
#
#         </tr>
#
#         <tr>
#
#               <td style="text-align: left; vertical-align: top">
#                 <pre>awards/amendment/rationale</pre>
#               </td>
#
#               <td style="text-align: left; vertical-align: top">
#                 <pre>10204</pre>
#               </td>
#
#               <td style="text-align: left; vertical-align: top">
#                 <pre>0.0</pre>
#               </td>
#
#               <td style="text-align: left; vertical-align: top">
#                 <pre>1</pre>
#               </td>
#
#               <td style="text-align: left; vertical-align: top">
#                 <pre>10204</pre>
#               </td>

# %% [markdown]
# Make first coverage report.
#
# The areas show how many fields each section of the schema has. The colours show how much coverage overall. Bright green 100%, grey 50% red 0%. The exact percentage is shown the the key at the top right when hovering over.
#
# 100% coverage is saying that for every OCID that it and all its possible child fields exist. So for example Awards has 71 sub fields and it is saying that all 71 for every OCID is populated.  If say only half the fields are ever used it will not be possible to get a coverage of over 50%

# %%
results = session.get_results('''
select path, exists_coverage, total_coverage, 1 as fields from coverage_stats order by length(path)
''')

results_for_gcharts = [['Field', 'Parent','Coverage','Fields'],
                       ['releases', None, 1, 0]]
for row in results['data']:
    split_path = row[0].split('/')
    parent = 'releases' if len(split_path) == 1 else '.'.join(split_path[:-1])
    results_for_gcharts.append(['.'.join(split_path), parent, float(row[3]), float(row[2])])
results_for_gcharts[:14]
# Out:
# [['Field', 'Parent', 'Coverage', 'Fields'],
#  ['releases', None, 1, 0],
#  ['id', 'releases', 1.0, 1.0],
#  ['tag', 'releases', 1.0, 1.0],
#  ['date', 'releases', 1.0, 1.0],
#  ['ocid', 'releases', 1.0, 1.0],
#  ['buyer', 'releases', 1.0, 0.38082287991637265],
#  ['tender', 'releases', 1.0, 0.05477263818110545],
#  ['awards', 'releases', 1.0, 0.10763108640080388],
#  ['language', 'releases', 1.0, 1.0],
#  ['planning', 'releases', 1.0, 0.0],
#  ['tender.id', 'tender', 1.0, 0.27156017248137987],
#  ['contracts', 'releases', 1.0, 0.14675200380326447],
#  ['awards.id', 'awards', 1.0, 0.3488827910623285]]

# %%
from IPython.core.display import display, HTML
import json

def display_treemap(results, id):
    display(HTML(
    '''
      <div id="chart_div_%s" style="width: 900px; height: 500px;"></div>
      <script type="text/javascript" src="https://www.gstatic.com/charts/loader.js"></script>    
      <script type="text/javascript">
      var checkExist%s = setInterval(function() {
        if (google) {
          google.charts.load('current', {'packages':['treemap']});
          google.charts.setOnLoadCallback(drawChart);
          function drawChart() {
            var data = google.visualization.arrayToDataTable(%s);

            tree = new google.visualization.TreeMap(document.getElementById('chart_div_%s'));

            tree.draw(data, {
              minColor: '#f00',
              midColor: '#ddd',
              maxColor: '#0d0',
              headerHeight: 15,
              fontColor: 'black',
              showScale: true,
              useWeightedAverageForAggregation:true
            });
          }
          clearInterval(checkExist%s);
         }
       }, 100);


        </script>


    ''' % (id, id, json.dumps(results_for_gcharts), id, id)
    ))
    
display_treemap(results_for_gcharts, '1')
# Out:
#       <div id="chart_div_1" style="width: 900px; height: 500px;"></div>
#       <script type="text/javascript" src="https://www.gstatic.com/charts/loader.js"></script>
#       <script type="text/javascript">
#       var checkExist1 = setInterval(function() {
#         if (google) {
#           google.charts.load('current', {'packages':['treemap']});
#           google.charts.setOnLoadCallback(drawChart);
#           function drawChart() {
#             var data = google.visualization.arrayToDataTable([["Field", "Parent", "Coverage", "Fields"], ["releases", null, 1, 0], ["id", "releases", 1.0, 1.0], ["tag", "releases", 1.0, 1.0], ["date", "releases", 1.0, 1.0], ["ocid", "releases", 1.0, 1.0], ["buyer", "releases", 1.0, 0.38082287991637265], ["tender", "releases", 1.0, 0.05477263818110545], ["awards", "releases", 1.0, 0.10763108640080388], ["language", "releases", 1.0, 1.0], ["planning", "releases", 1.0, 0.0], ["tender.id", "tender", 1.0, 0.27156017248137987], ["contracts", "releases", 1.0, 0.14675200380326447], ["awards.id", "awards", 1.0, 0.3488827910623285], ["buyer.name", "buyer", 1.0, 0.0], ["awards.date", "awards", 1.0, 0.3488827910623285], ["awards.items", "awards", 1.0, 0.09181126080587593], ["tender.value", "tender", 1.0, 0.0], ["tender.title", "tender", 1.0, 0.0], ["contracts.id", "contracts", 1.0, 0.7980203841630733], ["tender.items", "tender", 1.0, 0.07142193979657101], ["awards.value", "awards", 1.0, 0.3488827910623285], ["awards.title", "awards", 1.0, 0.0], ["tender.status", "tender", 1.0, 0.27156017248137987], ["buyer.address", "buyer", 1.0, 0.856624852998824], ["awards.status", "awards", 1.0, 0.3488827910623285], ["initiationType", "releases", 1.0, 1.0], ["contracts.value", "contracts", 1.0, 0.7943616882268392], ["contracts.items", "contracts", 1.0, 0.2099641007654377], ["tender.minValue", "tender", 1.0, 0.0], ["tender.items.id", "tender.items", 1.0, 0.2713641709133673], ["awards.items.id", "awards.items", 1.0, 0.3488827910623285], ["planning.budget", "planning", 1.0, 0.0], ["contracts.title", "contracts", 1.0, 0.0], ["contracts.status", "contracts", 1.0, 0.7980203841630733], ["tender.tenderers", "tender", 1.0, 0.0], ["buyer.identifier", "buyer", 1.0, 0.6], ["tender.amendment", "tender", 1.0, 0.07407225924474062], ["awards.documents", "awards", 1.0, 0.0], ["contracts.period", "contracts", 1.0, 0.7980203841630733], ["awards.suppliers", "awards", 1.0, 0.1439672350712139], ["tender.documents", "tender", 1.0, 0.10218541748333987], ["awards.amendment", "awards", 1.0, 0.0], ["awards.items.unit", "awards.items", 1.0, 0.0], ["contracts.awardID", "contracts", 1.0, 0.7980203841630733], ["tender.milestones", "tender", 1.0, 0.0], ["tender.items.unit", "tender.items", 1.0, 0.0], ["tender.awardPeriod", "tender", 1.0, 0.0], ["planning.rationale", "planning", 1.0, 0.0], ["planning.documents", "planning", 1.0, 0.0], ["awards.description", "awards", 1.0, 0.0], ["planning.budget.id", "planning.budget", 1.0, 0.0], ["contracts.items.id", "contracts.items", 1.0, 0.7978243825950607], ["tender.description", "tender", 1.0, 0.0], ["buyer.contactPoint", "buyer", 1.0, 0.0], ["tender.value.amount", "tender.value", 1.0, 0.0], ["buyer.identifier.id", "buyer.identifier", 1.0, 1.0], ["tender.tenderPeriod", "tender", 1.0, 0.27156017248137987], ["awards.documents.id", "awards.documents", 1.0, 0.0], ["tender.hasEnquiries", "tender", 1.0, 0.0], ["tender.documents.id", "tender.documents", 1.0, 0.2500980007840063], ["planning.budget.uri", "planning.budget", 1.0, 0.0], ["contracts.documents", "contracts", 1.0, 0.0], ["contracts.amendment", "contracts", 1.0, 0.3060237815235855], ["awards.value.amount", "awards.value", 1.0, 0.3488827910623285], ["tender.milestones.id", "tender.milestones", 1.0, 0.0], ["buyer.identifier.uri", "buyer.identifier", 1.0, 0.0], ["tender.awardCriteria", "tender", 1.0, 0.13578008624068993], ["tender.documents.url", "tender.documents", 1.0, 0.2500980007840063], ["tender.enquiryPeriod", "tender", 1.0, 0.0], ["awards.documents.url", "awards.documents", 1.0, 0.0], ["buyer.address.region", "buyer.address", 1.0, 0.856624852998824], ["contracts.dateSigned", "contracts", 1.0, 0.0], ["contracts.items.unit", "contracts.items", 1.0, 0.0], ["tender.value.currency", "tender.value", 1.0, 0.0], ["awards.amendment.date", "awards.amendment", 1.0, 0.0], ["awards.contractPeriod", "awards", 1.0, 0.0], ["awards.items.quantity", "awards.items", 1.0, 0.0], ["awards.suppliers.name", "awar ...

# %% [markdown]
# Make second coverage report.
#
# Similar to above but area is now decided by used fields in data (not total fields in schema). Colours use the same as above but exclude fields that do not exist in the data at all i.e green 100% means that of the child fields used at least once in the data all ocids have that field.

# %%
results = session.get_results('''
select path, exists_coverage, total_coverage, exists as fields from coverage_stats order by length(path)
''')

results_for_gcharts = [['Field', 'Parent','Coverage','Exists'],
                       ['releases', None, 1, 0]]
for row in results['data']:
    split_path = row[0].split('/')
    parent = 'releases' if len(split_path) == 1 else '.'.join(split_path[:-1])
    results_for_gcharts.append(['.'.join(split_path), parent, float(row[3]), float(row[2])])
display_treemap(results_for_gcharts, '2')
# Out:
#       <div id="chart_div_2" style="width: 900px; height: 500px;"></div>
#       <script type="text/javascript" src="https://www.gstatic.com/charts/loader.js"></script>
#       <script type="text/javascript">
#       var checkExist2 = setInterval(function() {
#         if (google) {
#           google.charts.load('current', {'packages':['treemap']});
#           google.charts.setOnLoadCallback(drawChart);
#           function drawChart() {
#             var data = google.visualization.arrayToDataTable([["Field", "Parent", "Coverage", "Exists"], ["releases", null, 1, 0], ["id", "releases", 1.0, 1.0], ["tag", "releases", 1.0, 1.0], ["date", "releases", 1.0, 1.0], ["ocid", "releases", 1.0, 1.0], ["buyer", "releases", 10.0, 0.38082287991637265], ["tender", "releases", 27.0, 0.05477263818110545], ["awards", "releases", 22.0, 0.10763108640080388], ["language", "releases", 1.0, 1.0], ["planning", "releases", 0.0, 0.0], ["tender.id", "tender", 1.0, 0.27156017248137987], ["contracts", "releases", 18.0, 0.14675200380326447], ["awards.id", "awards", 1.0, 0.3488827910623285], ["buyer.name", "buyer", 0.0, 0.0], ["awards.date", "awards", 1.0, 0.3488827910623285], ["awards.items", "awards", 5.0, 0.09181126080587593], ["tender.value", "tender", 0.0, 0.0], ["tender.title", "tender", 0.0, 0.0], ["contracts.id", "contracts", 1.0, 0.7980203841630733], ["tender.items", "tender", 5.0, 0.07142193979657101], ["awards.value", "awards", 3.0, 0.3488827910623285], ["awards.title", "awards", 0.0, 0.0], ["tender.status", "tender", 1.0, 0.27156017248137987], ["buyer.address", "buyer", 6.0, 0.856624852998824], ["awards.status", "awards", 1.0, 0.3488827910623285], ["initiationType", "releases", 1.0, 1.0], ["contracts.value", "contracts", 3.0, 0.7943616882268392], ["contracts.items", "contracts", 5.0, 0.2099641007654377], ["tender.minValue", "tender", 0.0, 0.0], ["tender.items.id", "tender.items", 1.0, 0.2713641709133673], ["awards.items.id", "awards.items", 1.0, 0.3488827910623285], ["planning.budget", "planning", 0.0, 0.0], ["contracts.title", "contracts", 0.0, 0.0], ["contracts.status", "contracts", 1.0, 0.7980203841630733], ["tender.tenderers", "tender", 0.0, 0.0], ["buyer.identifier", "buyer", 3.0, 0.6], ["tender.amendment", "tender", 2.0, 0.07407225924474062], ["awards.documents", "awards", 0.0, 0.0], ["contracts.period", "contracts", 3.0, 0.7980203841630733], ["awards.suppliers", "awards", 10.0, 0.1439672350712139], ["tender.documents", "tender", 4.0, 0.10218541748333987], ["awards.amendment", "awards", 0.0, 0.0], ["awards.items.unit", "awards.items", 0.0, 0.0], ["contracts.awardID", "contracts", 1.0, 0.7980203841630733], ["tender.milestones", "tender", 0.0, 0.0], ["tender.items.unit", "tender.items", 0.0, 0.0], ["tender.awardPeriod", "tender", 0.0, 0.0], ["planning.rationale", "planning", 0.0, 0.0], ["planning.documents", "planning", 0.0, 0.0], ["awards.description", "awards", 0.0, 0.0], ["planning.budget.id", "planning.budget", 0.0, 0.0], ["contracts.items.id", "contracts.items", 1.0, 0.7978243825950607], ["tender.description", "tender", 0.0, 0.0], ["buyer.contactPoint", "buyer", 0.0, 0.0], ["tender.value.amount", "tender.value", 0.0, 0.0], ["buyer.identifier.id", "buyer.identifier", 1.0, 1.0], ["tender.tenderPeriod", "tender", 3.0, 0.27156017248137987], ["awards.documents.id", "awards.documents", 0.0, 0.0], ["tender.hasEnquiries", "tender", 0.0, 0.0], ["tender.documents.id", "tender.documents", 1.0, 0.2500980007840063], ["planning.budget.uri", "planning.budget", 0.0, 0.0], ["contracts.documents", "contracts", 0.0, 0.0], ["contracts.amendment", "contracts", 3.0, 0.3060237815235855], ["awards.value.amount", "awards.value", 1.0, 0.3488827910623285], ["tender.milestones.id", "tender.milestones", 0.0, 0.0], ["buyer.identifier.uri", "buyer.identifier", 0.0, 0.0], ["tender.awardCriteria", "tender", 1.0, 0.13578008624068993], ["tender.documents.url", "tender.documents", 1.0, 0.2500980007840063], ["tender.enquiryPeriod", "tender", 0.0, 0.0], ["awards.documents.url", "awards.documents", 0.0, 0.0], ["buyer.address.region", "buyer.address", 1.0, 0.856624852998824], ["contracts.dateSigned", "contracts", 0.0, 0.0], ["contracts.items.unit", "contracts.items", 0.0, 0.0], ["tender.value.currency", "tender.value", 0.0, 0.0], ["awards.amendment.date", "awards.amendment", 0.0, 0.0], ["awards.contractPeriod", "awards", 0.0, 0.0], ["awards.items.quantity", "awards.items", 0.0, 0.0], ["awards.suppliers.name",  ...
