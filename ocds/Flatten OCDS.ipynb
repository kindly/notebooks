# %%
import noteql

# %%
session = noteql.Session('recursion', dburi='postgresql://noteql:noteql@localhost/noteql')

# %%
session.load_json('full-1.1.json', path_to_list='releases', table_name='import', field_name='releases', overwrite=True)
# Out:
# Total rows loaded 103

# %%
session.run_sql('''
drop table if exists releases;
select releases->> 'id' release_id, releases into releases from import
''')
# Out:
# 'Success'

# %%
session.run_sql('''
drop table if exists flattened;
WITH RECURSIVE all_paths(release_id, path, "value") AS (
    select release_id, 
       (key_value).key "path", 
       (key_value).value "value" from 
    (select release_id, jsonb_each(releases) key_value from releases) a
  UNION ALL
    (select release_id,
           case when key_value is not null then
               a.path || '/'::text || (key_value).key::text
           else
               a.path
           end "path",
           case when a.key_value is not null then
               (a.key_value).value
           else
               array_value
           end "value"
     from
        (select 
           release_id,
           path,
           jsonb_each(case when jsonb_typeof(value) = 'object' then value else '{}'::jsonb end) key_value,
           jsonb_array_elements(case when jsonb_typeof(value) = 'array' and jsonb_typeof(value -> 0) = 'object' then value else '[]'::jsonb end) "array_value"
           from all_paths
        ) a
   )
)
SELECT release_id, path,
   case when (jsonb_typeof(value) = 'array' and jsonb_typeof(value -> 0) = 'object') or jsonb_typeof(value) = 'object' then null else value end  
   into flattened
FROM all_paths
''')
# Out:
# 'Success'

# %%
session.run_sql('''
   select path, count(*) total, count(distinct release_id) distinct_release, count(distinct value) distinct_value from flattened group by 1 having  count(distinct release_id)  > 5 order by 3  desc
''')
# Out:
# <table>
#     <thead>
#     <tr>
#
#         <th style="text-align: left; vertical-align: top">path</th>
#
#         <th style="text-align: left; vertical-align: top">total</th>
#
#         <th style="text-align: left; vertical-align: top">distinct_release</th>
#
#         <th style="text-align: left; vertical-align: top">distinct_value</th>
#
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr>
#
#               <td style="text-align: left; vertical-align: top">
#                 <pre>tender/awardPeriod/endDate</pre>
#               </td>
#
#               <td style="text-align: left; vertical-align: top">
#                 <pre>103</pre>
#               </td>
#
#               <td style="text-align: left; vertical-align: top">
#                 <pre>103</pre>
#               </td>
#
#               <td style="text-align: left; vertical-align: top">
#                 <pre>103</pre>
#               </td>
#
#         </tr>
#
#         <tr>
#
#               <td style="text-align: left; vertical-align: top">
#                 <pre>awards/amendment</pre>
#               </td>
#
#               <td style="text-align: left; vertical-align: top">
#                 <pre>320</pre>
#               </td>
#
#               <td style="text-align: left; vertical-align: top">
#                 <pre>103</pre>
#               </td>
#
#               <td style="text-align: left; vertical-align: top">
#                 <pre>0</pre>
#               </td>
#
#         </tr>
#
#         <tr>
#
#               <td style="text-align: left; vertical-align: top">
#                 <pre>awards/amendment/amendsReleaseID</pre>
#               </td>
#
#               <td style="text-align: left; vertical-align: top">
#                 <pre>320</pre>
#               </td>
#
#               <td style="text-align: left; vertical-align: top">
#                 <pre>103</pre>
#               </td>
#
#               <td style="text-align: left; vertical-align: top">
#                 <pre>281</pre>
#               </td>
#
#         </tr>
#
#         <tr>
#
#               <td style="text-align: left; vertical-align: top">
#                 <pre>awards/amendment/changes</pre>
#               </td>
#
#               <td style="text-align: left; vertical-align: top">
#                 <pre>1260</pre>
#               </td>
#
#               <td style="text-align: left; vertical-align: top">
#                 <pre>103</pre>
#               </td>
#
#               <td style="text-align: left; vertical-align: top">
#                 <pre>0</pre>
#               </td>
#
#         </tr>
#
#         <tr>
#
#               <td style="text-align: left; vertical-align: top">
#                 <pre>tender/tenderers/contactPoint/telephone</pre>
#               </td>
#
#               <td style="text-align: left; vertical-align: top">
#                 <pre>297</pre>
#               </td>
#
#               <td style="text-align: left; vertical-align: top">
#                 <pre>103</pre>
#               </td>
#
#               <td style="text-align: left; vertical-align: top">
#                 <pre>268</pre>
#               </td>
#
#         </tr>
#
#         <tr>
#
#               <td style="text-align: left; vertical-align: top">
#                 <pre>tender/tenderers/contactPoint/url</pre>
#               </td>
#
#               <td style="text-align: left; vertical-align: top">
#                 <pre>297</pre>
#               </td>
#
#               <td style="text-align: left; vertical-align: top">
#                 <pre>103</pre>
#               </td>
#
#               <td style="text-align: left; vertical-align: top">
#                 <pre>291</pre>
#               </td>
#
#         </tr>
#
#         <tr>
#
#               <td style="text-align: left; vertical-align: top">
#                 <pre>tender/tenderers/id</pre>
#               </td>
#
#               <td style="text-align: left; vertical-align: top">
#                 <pre>297</pre>
#               </td>
#
#               <td style="text-align: left; vertical-align: top">
#                 <pre>103</pre>
#               </td>
#
#               <td style="text-align: left; vertical-align: top">
#                 <pre>297</pre>
#               </td>
#
#         </tr>
#
#         <tr>
#
#               <td style="text-align: left; vertical-align: top">
#                 <pre>tender/tenderers/identifier</pre>
#               </td>
#
#               <td style="text-align: left; vertical-align: top">
#                 <pre>297</pre>
#               </td>
#
#               <td style="text-align: left; vertical-align: top">
#                 <pre>103</pre>
#               </td>
#
#               <td style="text-align: left; vertical-align: top">
#                 <pre>0</pre>
#               </td>
#
#         </tr>
#
#         <tr>
#
#               <td style="text-align: left; vertical-align: top">
#                 <pre>tender/tenderers/identifier/id</pre>
#               </td>
#
#               <td style="text-align: left; vertical-align: top">
#                 <pre>297</pre>
#               </td>
#
#               <td style="text-align: left; vertical-align: top">
#                 <pre>103</pre>
#               </td>
#
#               <td style="text-align: left; vertical-align: top">
#                 <pre>297</pre>
#               </td>
#
#         </tr>
#
#         <tr>
#
#               <td style="text-align: left; vertical-align: top">
#                 <pre>tender/tenderers/identifier/legalName</pre>
#               </td>
#
#               <td style="text-align: left; vertical-align: top">
#                 <pre>297</pre>
#               </td>
#
#               <td style="text-align: left; vertical-align: top">
#                 <pre>103</pre>
#               </td>
#
#               <td style="text-align: left; vertical-align: top">
#                 <pre>273</pre>
#               </td>
#
#         </tr>
#
#         <tr>
#
#               <td style="text-align: left; vertical-align: top">
#                 <pre>tender/tenderers/identifier/scheme</pre>
#               </td>
#
#               <td style="text-align: left; vertical-align: top">
#                 <pre>297</pre>
#               </td>
#
#               <td style="text-align: left; vertical-align: top">
#                 <pre>103</pre>
#               </td>
#
#               <td style="text-align: left; vertical-align: top">
#                 <pre>270</pre>
#               </td>
#
#         </tr>
#
#         <tr>
#
#               <td style="text-align: left; vertical-align: top">
#                 <pre>tender/tenderers/identifier/uri</pre>
#               </td>
#
#               <td style="text-align: left; vertical-align: top">
#                 <pre>297</pre>
#               </td>
#
#               <td style="text-align: left; vertical-align: top">
#                 <pre>103</pre>
#               </td>
#
#               <td style="text-align: left; vertical-align: top">
#                 <pre>296</pre>
#               </td>
#
#         </tr>
#
#         <tr>
#
#               <td style="text-align: left; vertical-align: top">
#                 <pre>tender/tenderers/name</pre>
#               </td>
#
#               <td style="text-align: left; vertical-align: top">
#                 <pre>297</pre>
#               </td>
#
#               <td style="text-align: left; vertical-align: top">
#                 <pre>103</pre>
#               </td>
#
#               <td style="text-align: left; vertical-align: top">
#                 <pre>270</pre>
#               </td>
#
#         </tr>
#
#         <tr>
#
#               <td style="text-align: left; vertical-align: t

# %%
results = session.get_results('''
select path, count(*) total, count(distinct release_id) distinct_release, count(distinct value) distinct_value from flattened group by 1 having  count(distinct release_id)  > 5 order by length(path)'''
                             )

# %%
results_for_gcharts = [['Field', 'Parent','Total Count','Distinct Releases'],
                       ['releases', None, 103, 0]]
for row in results['data']:
    split_path = row[0].split('/')
    parent = 'releases' if len(split_path) == 1 else '.'.join(split_path[:-1])
    results_for_gcharts.append(['.'.join(split_path), parent, int(row[1]), int(row[2])])
results_for_gcharts[:14]
# Out:
# [['Field', 'Parent', 'Total Count', 'Distinct Releases'],
#  ['releases', None, 103, 0],
#  ['id', 'releases', 103, 103],
#  ['tag', 'releases', 103, 103],
#  ['ocid', 'releases', 103, 103],
#  ['date', 'releases', 103, 103],
#  ['buyer', 'releases', 103, 103],
#  ['awards', 'releases', 423, 103],
#  ['tender', 'releases', 103, 103],
#  ['parties', 'releases', 412, 103],
#  ['planning', 'releases', 103, 103],
#  ['language', 'releases', 103, 103],
#  ['buyer.id', 'buyer', 103, 103],
#  ['contracts', 'releases', 407, 103]]

# %%
from IPython.core.display import display, HTML
import json
display(HTML(
'''
  <div id="chart_div" style="width: 900px; height: 500px;"></div>
  <script type="text/javascript" src="https://www.gstatic.com/charts/loader.js"></script>    
  <script type="text/javascript">
  var checkExist = setInterval(function() {
    if (google) {
      google.charts.load('current', {'packages':['treemap']});
      google.charts.setOnLoadCallback(drawChart);
      function drawChart() {
        var data = google.visualization.arrayToDataTable(%s);

        tree = new google.visualization.TreeMap(document.getElementById('chart_div'));

        tree.draw(data, {
          minColor: '#f00',
          midColor: '#ddd',
          maxColor: '#0d0',
          headerHeight: 15,
          fontColor: 'black',
          showScale: true
        });
      }
      clearInterval(checkExist);
     }
   }, 100);
      

    </script>


''' % json.dumps(results_for_gcharts)
))
# Out:
#   <div id="chart_div" style="width: 900px; height: 500px;"></div>
#   <script type="text/javascript" src="https://www.gstatic.com/charts/loader.js"></script>
#   <script type="text/javascript">
#   var checkExist = setInterval(function() {
#     if (google) {
#       google.charts.load('current', {'packages':['treemap']});
#       google.charts.setOnLoadCallback(drawChart);
#       function drawChart() {
#         var data = google.visualization.arrayToDataTable([["Field", "Parent", "Total Count", "Distinct Releases"], ["releases", null, 103, 0], ["id", "releases", 103, 103], ["tag", "releases", 103, 103], ["ocid", "releases", 103, 103], ["date", "releases", 103, 103], ["buyer", "releases", 103, 103], ["awards", "releases", 423, 103], ["tender", "releases", 103, 103], ["parties", "releases", 412, 103], ["planning", "releases", 103, 103], ["language", "releases", 103, 103], ["buyer.id", "buyer", 103, 103], ["contracts", "releases", 407, 103], ["awards.id", "awards", 320, 103], ["tender.id", "tender", 103, 103], ["buyer.name", "buyer", 103, 103], ["parties.id", "parties", 309, 103], ["awards.date", "awards", 320, 103], ["parties.name", "parties", 309, 103], ["awards.title", "awards", 320, 103], ["awards.value", "awards", 320, 103], ["tender.value", "tender", 103, 103], ["awards.items", "awards", 1288, 103], ["contracts.id", "contracts", 304, 103], ["tender.title", "tender", 103, 103], ["tender.items", "tender", 423, 103], ["tender.status", "tender", 88, 88], ["awards.status", "awards", 263, 100], ["parties.roles", "parties", 309, 103], ["buyer.address", "buyer", 103, 103], ["initiationType", "releases", 103, 103], ["planning.budget", "planning", 103, 103], ["parties.address", "parties", 309, 103], ["contracts.value", "contracts", 304, 103], ["tender.items.id", "tender.items", 320, 103], ["tender.minValue", "tender", 103, 103], ["awards.items.id", "awards.items", 968, 103], ["contracts.items", "contracts", 1201, 103], ["contracts.title", "contracts", 304, 103], ["contracts.period", "contracts", 304, 103], ["awards.documents", "awards", 1230, 103], ["tender.amendment", "tender", 103, 103], ["awards.suppliers", "awards", 1278, 103], ["relatedProcesses", "releases", 414, 103], ["awards.amendment", "awards", 320, 103], ["contracts.status", "contracts", 248, 101], ["tender.documents", "tender", 422, 103], ["tender.tenderers", "tender", 400, 103], ["buyer.identifier", "buyer", 103, 103], ["tender.amendments", "tender", 391, 103], ["contracts.awardID", "contracts", 304, 103], ["awards.items.unit", "awards.items", 968, 103], ["awards.amendments", "awards", 1321, 103], ["tender.items.unit", "tender.items", 320, 103], ["tender.milestones", "tender", 399, 103], ["planning.budget.id", "planning.budget", 103, 103], ["buyer.contactPoint", "buyer", 103, 103], ["planning.documents", "planning", 426, 103], ["contracts.items.id", "contracts.items", 897, 103], ["tender.description", "tender", 103, 103], ["awards.description", "awards", 320, 103], ["planning.rationale", "planning", 103, 103], ["tender.awardPeriod", "tender", 103, 103], ["parties.identifier", "parties", 309, 103], ["awards.suppliers.id", "awards.suppliers", 958, 103], ["tender.hasEnquiries", "tender", 103, 103], ["awards.documents.id", "awards.documents", 910, 103], ["tender.documents.id", "tender.documents", 319, 103], ["tender.amendment.id", "tender.amendment", 103, 103], ["tender.value.amount", "tender.value", 103, 103], ["relatedProcesses.id", "relatedProcesses", 311, 103], ["contracts.amendment", "contracts", 304, 103], ["planning.milestones", "planning", 413, 103], ["planning.budget.uri", "planning.budget", 103, 103], ["buyer.identifier.id", "buyer.identifier", 103, 103], ["tender.tenderers.id", "tender.tenderers", 297, 103], ["awards.amendment.id", "awards.amendment", 320, 103], ["awards.value.amount", "awards.value", 320, 103], ["tender.tenderPeriod", "tender", 103, 103], ["contracts.documents", "contracts", 1186, 103], ["contracts.items.unit", "contracts.items", 897, 103], ["tender.awardCriteria", "tender", 103, 103], ["relatedProcesses.uri", "relatedProcesses", 311, 103], ["awards.items.unit.id", "awards.items.unit", 968, 103], ["tender.documents.url", "tender.documents", 319, 103], ["buyer.address.region", "buyer.address", 103, 103], ["buyer.identifier.uri", "buyer.identifier", 103, 103], ["tender.items.unit.id", "tender.items.unit", 320, 103], ["tender.enquiryPeriod", "tend ...
